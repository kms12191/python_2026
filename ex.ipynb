# %%
a= "hello \nhi"

# %%
print(a)
# Out:
# hello
# hi

# %%
a= """hello 
hi"""

# %%
print(a)
# Out:
# hello
# hi

# %%
a = "hello"
b = ' world'
c = a+b

# %%
c
# Out:
# 'hello world'

# %%
len(a+b)
# Out:
# 11

# %%
c[0]
# Out:
# 'h'

# %%
c[10]
# Out:
# 'd'

# %%
c[5]
# Out:
# ' '

# %%
c[:5]
# Out:
# 'hello'

# %%
c[6:10]
# Out:
# 'worl'

# %%
a = 'hello worlf'
a
# Out:
# 'hello worlf'

# %%
a[10]
# Out:
# 'f'

# %%
b = a[:10] + 'd'

# %%
b
# Out:
# 'hello world'

# %%
num =10
day = 'three'

"I ate %d apples. so I was sick for %s days." %(day, num)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 4
#       1 num =10
#       2 day = 'three'
# ----> 4 "I ate %d apples. so I was sick for %s days." %(day, num)
#
# TypeError: %d format: a real number is required, not str

# %%
s1 = set('Kang - Min_Sik, 강민식!')

# %%
s1
# Out:
# {' ',
#  '!',
#  ',',
#  '-',
#  'K',
#  'M',
#  'S',
#  '_',
#  'a',
#  'g',
#  'i',
#  'k',
#  'n',
#  '강',
#  '민',
#  '식'}

# %%
a = [1,2,3,1,2,3]
a.remove(3)

# %%
a
# Out:
# [1, 2, 1, 2, 3]

# %%
a.remove(3)
a
# Out:
# [1, 2, 1, 2]

# %%
a = [1,2,3,4]
a
# Out:
# [1, 2, 3, 4]

# %%
a.extend([5,6])

# %%
a
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a.append([5,6])
a
# Out:
# [1, 2, 3, 4, 5, 6, [5, 6]]

# %%
type(a)
# Out:
# list
