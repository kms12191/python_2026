# %% [markdown]
# # 클래스(class)

# %% [markdown]
# ## 1. 계산기 프로그램을 만들며 클래스 알아보기

# %%
result = 0 #초기값

def add(num):
    global result
    result += num
    return result

print(add(3))
print(add(4))
# Out:
# 3
# 7

# %%
result
# Out:
# 7

# %%
# 2대의 계산기
result1 = 0
result2 = 0

def add1(num):
    global result1
    result1 += num
    return result1

def add2(num):
    global result2
    result2 += num
    return result2

print(add1(3))
print(add1(4))
print(add2(3))
print(add2(7))
# Out:
# 3
# 7
# 3
# 10

# %%
# 여러대 계산기를 클래스로 해결하기
class Calculator: # 클래스 = 설계도
    def __init__(self):
        self.result = 0 #초기값 설정

    def add(self, num):
        self.result += num
        return self.result

# %%
cal1 = Calculator()
cal2 = Calculator()

# %%
print(cal1.add(3))
# Out:
# 3

# %%
print(cal1.add(4))
# Out:
# 7

# %%
print(cal2.add(3))
# Out:
# 3

# %%
print(cal2.add(7))
# Out:
# 10

# %% [markdown]
# ## 2. 클래스(class)과 객체(object)

# %%
# 클래스 선언
class Cookie: 
    pass

# %%
# 객체 생성
a = Cookie()
b = Cookie()

# %% [markdown]
# ## 3. 사칙연산 클래스 만들기

# %%
# 1) 클래스 구조 만들기
class FourCal:
    pass

# %%
# 객체 생성
a = FourCal()

# %%
type(a)
# Out:
# __main__.FourCal

# %%
a

# %%
# 2) 객체에서 연산할 숫자 2개 지정하기
class FourCal:   # 클래스 선언
    def setdata(self, first, second):
        self.first = first
        self.second = second

# %%
# 객체 생성
a = FourCal()

# %%
a.setdata(4,2)

# %%
a.first
# Out:
# 4

# %%
a.second
# Out:
# 2

# %%
# b객체 생성
b = FourCal()

# %%
b.setdata(7,3)

# %%
b.first
# Out:
# 7

# %%
b.second
# Out:
# 3

# %%
# 3) 더하기 기능 만들기
#class 선언
class FourCal:   # 클래스 선언
    def setdata(self, first, second):
        self.first = first
        self.second = second

    def add(self):
        result = self.first + self.second
        return result

# %%
# 객체 생성
a = FourCal()
a.setdata(4,2)
a.add()
# Out:
# 6

# %%
# 4) 곱하기, 빼기, 나누기 기능 만들기
class FourCal:   # 클래스 선언
    def setdata(self, first, second):
        self.first = first
        self.second = second

    def add(self):
        result = self.first + self.second
        return result

    def sub(self):
        result = self.first - self.second
        return result

    def mul(self):
        result = self.first * self.second
        return result
        
    def div(self):
        result = self.first / self.second
        return result

# %%
# 객체 생성
a = FourCal()
a.setdata(4,2)
a.add()
# Out:
# 6

# %%
a.sub()
# Out:
# 2

# %%
a.mul()
# Out:
# 8

# %%
a.div()
# Out:
# 2.0

# %%
b = FourCal()
b.setdata(3,8)
b.add()
# Out:
# 11

# %%
b.sub()
# Out:
# -5

# %%
b.mul()
# Out:
# 24

# %%
b.div()
# Out:
# 0.375

# %%
c= FourCal()

# %%
c.add() # setdata() 숫자 2개를 입력 안함
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 c.add() # setdata() 숫자 2개를 입력 안함
#
# Cell In[51], line 8, in FourCal.add(self)
#       7 def add(self):
# ----> 8     result = self.first + self.second
#       9     return result
#
# AttributeError: 'FourCal' object has no attribute 'first'

# %% [markdown]
# ## 4. 생성자(Consturctor)

# %% [markdown]
# - 생성자는 객체가 생성될 때 자동으로 실행되는 매서드
# - 객체에 초기값을 설정하는 역할

# %%
class FourCal:   
    # 생성자 함수 : 객체생성시 자동 호출
    def __init__(self, first, second):
        self.first = first
        self.second = second

    def add(self):
        result = self.first + self.second
        return result

    def sub(self):
        result = self.first - self.second
        return result

    def mul(self):
        result = self.first * self.second
        return result
        
    def div(self):
        result = self.first / self.second
        return result

# %%
a = FourCal()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 a = FourCal()
#
# TypeError: FourCal.__init__() missing 2 required positional arguments: 'first' and 'second'

# %%
a = FourCal(4,2)

# %%
a.add()
# Out:
# 6

# %%
a.sub()
# Out:
# 2

# %%
a.mul()
# Out:
# 8

# %%
a.div()
# Out:
# 2.0

# %%
a.first
# Out:
# 4

# %%
a.second
# Out:
# 2

# %% [markdown]
# ## 5. 클래스의 상속

# %%
class MoreFourCal(FourCal):  # FourCal클래스 상속
    pass

# %%
# 객체 생성
a = MoreFourCal(4,2)

# %%
a.add()
# Out:
# 6

# %%
a.sub()
# Out:
# 2

# %%
a.mul()
# Out:
# 8

# %%
a.div()
# Out:
# 2.0

# %%
class MoreFourCal(FourCal):  # FourCal클래스 상속
    def pow(self):
        result = self.first ** self.second
        return result

# %%
b = MoreFourCal(4,2)
b.pow()
# Out:
# 16

# %%
b.add()
# Out:
# 6

# %%
c = FourCal(4,0)

# %%
c.add()
# Out:
# 4

# %%
c.sub()
# Out:
# 4

# %%
c.mul()
# Out:
# 0

# %%
c.div()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 c.div()
#
# Cell In[63], line 20, in FourCal.div(self)
#      19 def div(self):
# ---> 20     result = self.first / self.second
#      21     return result
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## 6. 매서드 오버라이딩(매서드 재정의)

# %%
# 0으로 나눌때 오류가 아닌 0을 리턴하도록 처리하려면?

# %%
class SafeFourCal(FourCal):
    def div(self):  # 매서드 오버라이드 : 상속받는 클래스의 매서드 이름을 똑같이 사용하녀 함수를 재정의
        if self.second == 0:
            return 0
        else:
            return self.first / self.second

# %%
a = SafeFourCal(4,0)

# %%
a.div()
# Out:
# 0

# %% [markdown]
# ## 7. 클래스 변수

# %% [markdown]
# - 클래스로 만든 객체가 모두 공유하는 변수

# %%
# 클래스 변수 선언
class Family:
    lastname = '강'

# %%
# 클래스 변수사용

# %%
Family.lastname
# Out:
# '강'

# %%
a=Family()
b=Family()

# %%
a.lastname
# Out:
# '강'

# %%
b.lastname
# Out:
# '강'

# %%
Family.lastname='박'    # 클래스 변수 변경

# %%
Family.lastname
# Out:
# '박'

# %%
a.lastname
# Out:
# '박'

# %%
b.lastname
# Out:
# '박'

# %%
# 객체에서 클래스 변수 변경
a.lastname = '최'

# %%
a.lastname #    클래스 변수를 변경한 것이 아니고 a객체의 인스턴스 변수를 새롭게 생성
# Out:
# '최'

# %%
b.lastname
# Out:
# '박'

# %%
Family.lastname     # 클래스 변수는 변경 안되었음
# Out:
# '박'
